# %%
import pandas as pd
import matplotlib.pyplot as plt
#! pip install mpld3
import mpld3
import json

# %%
usa_tickets_data = pd.read_json('mattgawarecki_ticket_to_ride/usa.tickets.json')
usa_tickets_data.head()
# Out:
#                       cities  points
# 0            [Boston, Miami]      12
# 1         [Calgary, Phoenix]      13
# 2  [Calgary, Salt Lake City]       7
# 3     [Chicago, New Orleans]       7
# 4        [Chicago, Santa Fe]       9

# %%
usa_cities_data = pd.read_json('mattgawarecki_ticket_to_ride/usa.cities.json')
usa_cities_data.head()
# Out:
#             0
# 0     Atlanta
# 1      Boston
# 2     Calgary
# 3  Charleston
# 4     Chicago

# %%
usa_routes_data = pd.read_json('mattgawarecki_ticket_to_ride/usa.routes.json')
usa_routes_data.describe()
# Out:
#                                                   Atlanta  \
# count                                                   5
# unique                                                  5
# top     {'distance': 1, 'connections': [{'color': 'Any...
# freq                                                    1
#
#                                                    Boston  \
# count                                                   2
# unique                                                  2
# top     {'distance': 2, 'connections': [{'color': 'Any...
# freq                                                    1
#
#                                                   Calgary  \
# count                                                   4
# unique                                                  3
# top     {'distance': 4, 'connections': [{'color': 'Any...
# freq                                                    2
#
#                                                Charleston  \
# ...

# %%
_usa_tickets_1910_data = pd.read_json('mattgawarecki_ticket_to_ride/1910.usa.tickets.json')
_usa_tickets_1910_data = _usa_tickets_1910_data[['cities', 'points']]
_usa_tickets_1910_data.head(10)
# Out:
#                   cities  points
# 0   [Calgary, Nashville]      14
# 1     [Chicago, Atlanta]       5
# 2      [Chicago, Boston]       7
# 3    [Chicago, New York]       5
# 4  [Denver, Saint Louis]       6
# 5       [Duluth, Dallas]       7
# 6  [Houston, Washington]      10
# 7  [Kansas City, Boston]      11
# 8     [Las Vegas, Miami]      21
# 9  [Las Vegas, New York]      19

# %%
yellow_P1 = pd.read_json('yellow_p1.json')
red_P2 =  pd.read_json('red_P2.json')
green_P3 = pd.read_json('green_P3.json') 
blue_P4 = pd.read_json('blue_P4.json')
